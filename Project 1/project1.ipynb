# %%
#import csv
from pathlib import Path
import pandas as pd

# %%
#import tution.csv
tuition=pd.read_csv(
    Path('./Resources/tuition.csv')
)
tuition.head(110)
# Out:
#                                                   year All insti-tutions  \
# 0                                             1963-64           $10,648
# 1                                             1968-69             10,762
# 2                                             1969-70             10,868
# 3                                             1970-71             10,948
# 4                                             1971-72             11,066
# ..                                                 ...               ...
# 105                                           2017-18             18,872
# 106                                           2018-19             19,098
# 107                                            2019-20            19,270
# 108                                            2020-21            19,374
# 109  Private \n   nonprofit and\n   for-profit\n   ...               NaN
#
#        4-year   2-year All insti-tutions.1 4-year.1 2-year.1  \
# ...

# %%
#public tution price 2021 for all institutions

public_2021_df=(tuition[['year','All insti-tutions','4-year','2-year']])
public_2021_df.head()
# Out:
#        year All insti-tutions    4-year   2-year
# 0  1963-64           $10,648   $10,973   $6,616
# 1  1968-69             10,762    11,401    7,769
# 2  1969-70             10,868    11,665    7,589
# 3  1970-71             10,948    11,820    7,422
# 4  1971-72             11,066    12,007    7,493

# %%
public_2021_df.iloc[105:109,:]
# Out:
#          year All insti-tutions  4-year  2-year
# 105  2017-18             18,872  21,263  10,903
# 106  2018-19             19,098  21,401  11,378
# 107   2019-20            19,270  21,520  11,314
# 108   2020-21            19,374  21,337  11,557

# %%
#private costs
private_df=(tuition[['year','All insti-tutions','4-year','2-year']])
private_df.iloc[160:164,:]
# Out:
#          year All insti-tutions  4-year  2-year
# 160  2017-18             45,257  45,743  27,146
# 161  2018-19             46,043  46,414  29,695
# 162   2019-20            46,612  46,982  27,359
# 163   2020-21            45,920  46,313  25,667

# %%
#non-profit
non_profit_df=(tuition[['year','All insti-tutions','4-year','2-year']])
non_profit_df.iloc[183:187,:]
# Out:
#              year All insti-tutions  4-year  2-year
# 183      2017-18             48,794  48,938  28,136
# 184      2018-19             49,281  49,408  28,966
# 185       2019-20            49,939  50,083  29,077
# 186       2020-21            49,210  49,344  27,740

# %%
#for profit

for_profit_df=(tuition[['year','All insti-tutions','4-year','2-year']])
for_profit_df.iloc[206:210,:]
# Out:
#              year All insti-tutions  4-year  2-year
# 206      2017-18             27,843  28,002  26,583
# 207      2018-19             28,096  27,611  31,219
# 208      2019-20             28,196  28,334  25,546
# 209       2020-21            27,470  27,723  23,599
